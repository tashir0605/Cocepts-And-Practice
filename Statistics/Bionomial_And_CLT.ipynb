# %% [markdown]
# <a href="https://colab.research.google.com/github/tashir0605/Cocepts-And-Practice/blob/main/Statistics/Bionomial_And_CLT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n=10
p=0.5
sie=1000

bionomial_dist=np.random.binomial(n,p,sie)

plt.hist(bionomial_dist,density=True)
plt.show()

# %%
bionomial_dist
# Out:
# array([4, 7, 4, 3, 3, 2, 4, 7, 4, 5, 6, 5, 5, 5, 5, 8, 5, 7, 5, 5, 6, 6,
#        6, 2, 5, 5, 4, 4, 5, 5, 4, 9, 1, 5, 5, 7, 6, 5, 6, 4, 5, 7, 4, 4,
#        5, 7, 4, 4, 2, 6, 2, 2, 5, 3, 4, 5, 3, 3, 4, 7, 4, 4, 1, 5, 3, 8,
#        3, 3, 7, 3, 6, 7, 5, 7, 5, 6, 7, 3, 4, 7, 5, 3, 5, 6, 5, 6, 5, 5,
#        2, 6, 7, 6, 3, 4, 1, 3, 6, 4, 7, 4, 4, 6, 6, 7, 1, 7, 3, 5, 5, 6,
#        6, 6, 5, 6, 5, 8, 6, 6, 5, 4, 7, 6, 6, 4, 6, 1, 4, 6, 6, 4, 6, 6,
#        3, 7, 6, 6, 2, 5, 7, 6, 6, 5, 6, 6, 8, 6, 7, 6, 5, 5, 7, 4, 4, 8,
#        3, 3, 4, 5, 6, 6, 5, 4, 7, 7, 3, 4, 5, 4, 6, 6, 4, 5, 7, 5, 7, 5,
#        4, 8, 2, 7, 5, 6, 5, 7, 4, 4, 7, 1, 5, 2, 5, 3, 3, 4, 6, 3, 4, 5,
#        6, 9, 4, 6, 8, 4, 4, 5, 4, 6, 5, 4, 6, 6, 4, 3, 6, 3, 5, 7, 7, 5,
#        7, 5, 5, 4, 5, 4, 5, 3, 7, 5, 6, 6, 6, 1, 6, 3, 6, 5, 5, 6, 3, 7,
#        4, 4, 4, 3, 4, 2, 4, 4, 7, 1, 5, 5, 7, 3, 6, 4, 2, 6, 5, 3, 5, 8,
#        5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 4, 4, 3, 7, 6, 6, 5, 4, 5, 3, 6, 5,
# ...

# %%
bionomial_dist.shape
# Out:
# (1000,)

# %% [markdown]
# if you see the above array it is
#
# let take a element of the bionimial_dist[5] =2
#
# it signifies that aapne 10 trial kiya in one event and ye event ko 1000 baar perform kiya and usme jb aap uss event ko aap 5wi baar kr rhe the to to unn trials me se 2 me head aaya which consider as success out of 10.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
