# %% [markdown]
# <a href="https://colab.research.google.com/github/tashir0605/Cocepts-And-Practice/blob/main/LLM_from_Scratch/Tokenizer_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tokenization Proces
#
#
#  For example:
# 1. You take the Harry pOTTER BOOKS
# dIVEIDE THE BOOKS Into sentences
#
# 2. Now you are further divide the senteces into individual words
#
# 3. you provide those words and subwords with tokens and then convert the tokens into token Id's

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 with open("the-verdict.txt","r",encoding="utf-8")as f:
  raw_text=f.read()

print("Total number of character:", len(raw_text))
print(raw_text[:99])
# Out:
# Total number of character: 20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %%
import re

text="Hello, world. This, is a test."
result=re.split(r'(/s)', text)

print(result)
# Out:
# ['Hello, world. This, is a test.']

# %%
result=re.split(r'([.,]|/s)', text)
result
# Out:
# ['Hello', ',', ' world', '.', ' This', ',', ' is a test', '.', '']

# %%
result=[item for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', ' world', '.', ' This', ',', ' is a test', '.']

# %%
text="Hello, World. Is this-- a test?"

result=re.split(r'([,?"!;.()\']|--|\s)' ,text)
result
# Out:
# ['Hello',
#  ',',
#  '',
#  ' ',
#  'World',
#  '.',
#  '',
#  ' ',
#  'Is',
#  ' ',
#  'this',
#  '--',
#  '',
#  ' ',
#  'a',
#  ' ',
#  'test',
#  '?',
#  '']

# %%
result=[item.strip() for item in result if item.strip()]
result
# Out:
# ['Hello', ',', 'World', '.', 'Is', 'this', '--', 'a', 'test', '?']

# %%
preprocessed=re.split(r'([,;"?/:_()\']|--|\s)',raw_text)
preprocessed=[item.strip() for item in preprocessed if item.strip()]

# %%
preprocessed[:30]
# Out:
# ['I',
#  'HAD',
#  'always',
#  'thought',
#  'Jack',
#  'Gisburn',
#  'rather',
#  'a',
#  'cheap',
#  'genius',
#  '--',
#  'though',
#  'a',
#  'good',
#  'fellow',
#  'enough',
#  '--',
#  'so',
#  'it',
#  'was',
#  'no',
#  'great',
#  'surprise',
#  'to',
#  'me',
#  'to',
#  'hear',
#  'that',
#  ',',
#  'in']

# %%
len(preprocessed)
# Out:
# 4476
