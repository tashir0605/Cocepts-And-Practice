# %% [markdown]
# <a href="https://colab.research.google.com/github/tashir0605/Cocepts-And-Practice/blob/main/Pytorch/autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WHY

# %% [markdown]
# # 🔁 Autograd in PyTorch
#
# **Autograd** in PyTorch is a core feature that **automatically computes gradients (derivatives)** for tensors used in neural networks.
#
# ## 🔍 Short Explanation:
# - It enables **automatic backpropagation** by **tracking operations** on tensors.
# - When you call **`.backward()`** on a loss tensor, PyTorch **calculates all gradients** needed for optimization.
# - This eliminates the need to **manually compute derivatives**.
#
# ✅ **Why it's useful**:
# - Saves time
# - Reduces errors
# - Essential for training deep learning models

# %% [markdown]
# ![Screenshot from 2025-06-22 12-54-40.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-06-22 12-59-55.png](data:image/png;base64,...)
